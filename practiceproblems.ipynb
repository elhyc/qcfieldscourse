# %% [markdown]
# # Further exercises for practice
#
# For optional practice, here are some exercises you can do to try out python/quantum program flow compatibility.

# %% [markdown]
# ## Creating circuits that prepare superposition states

# %% [markdown]
# Given an $n$ qubit system $\mathcal{H}(n)$, we have $2^{n}$ computational basis states $\ket{ i_{0}, \cdots , i_{n-1}}$. Write a python function that does the following
#
# Input: an integer $n$
#
# Returns a ```QuantumCircuit```  with a qubit register of size $n$, and prepares the equal superposition state
#
# $$
# \sum_{ i_{j} = 0, 1 } \frac{1}{\sqrt{2^{n}}} \big( \ket{i_{0}, \cdots , i_{n-1}})
# $$

# %%
### try to find your own import statements!

# %% [markdown]
# Now, write a python function that does the following
#
# Input: an integer $n$, an boolean ```parity```
#
# Returns a ```QuantumCircuit```  with a qubit register of size $n$.. and if ```parity``` is set to true, prepare an equal superposition of all computational basis states representing even numbers, if ```parity``` is false, prepare an equal superposition of all computational basis states representing odd numbers.

# %%
### your code here

# %% [markdown]
# Write a python function that does the following
#
# Input: an integer $n$, a list of bitstrings of size $n$
#
# Returns a ```QuantumCircuit```  with a qubit register of size $n$.. and prepare an equal superposition of all the computational basis states encoding the bitstrings from the list.
#
# For example, given $n=3$ and L = [ '010', '001' ], the state to be prepared should be
#
# $$
# \frac{1}{\sqrt{2}} ( \ket{010} + \ket{001} )
# $$

# %%
### your code here

# %% [markdown]
# Implement a quantum circuit that takes the input $\ket{00}$ state to the final state of
#
# $$
# \frac{1}{\sqrt{2}}\ket{00} + \frac{1}{2} \ket{10} + \frac{1}{2} \ket{11}
# $$

# %%
### your code here
